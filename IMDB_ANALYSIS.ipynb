# %% [markdown]
# IMPORT REQUARIED LIBRARY

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# LOAD THE DATASET

# %%
movies = pd.read_excel(r'D:\PROJECT_DATA\IMDB_Movies_Data.xlsx')
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#CHECK SHAPE AND SIZE OF THE DATA
movies.shape
# Out:
# (5043, 28)

# %%
#check the columns name
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#check the data types like FLOAT,INT
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews          object
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
#CHECK THE NULL VALUES
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(movies.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# WHITE LINE IN GRAPH SHOW THE NULL VALUS

# %%
plt.figure(figsize=(20,15))
sns.heatmap(movies.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#stastic summary of the datase
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
#check basic information about the data like data type , columns name etc
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
#find the objective/catgrcl columns
cat=[i for i in movies.columns if movies[i].dtype==object]

# %%
cat
# Out:
# ['color',
#  'director_name',
#  'actor_2_name',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'actor_3_name',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating']

# %% [markdown]
# FIND THE COLUMNS WISE % OF NULL VALUES

# %%
round(movies.isnull().sum()/len(movies.index)*100,2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.40
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# # remove/fill null values,
# #drop the unnessasary columns

# %%
movies["color"].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
#maximum movies in color so we can drop this column
movies.drop('color',axis=1,inplace=True)

# %%
#remove movie_imdb_link the column is not required so we can remove the column
movies.drop(['movie_imdb_link'],axis=1,inplace=True)

# %%
# We can remove the null values from the dataset where the count is less . so that we don't loose much data 

movies.dropna(axis=0,subset=['actor_1_facebook_likes','actor_1_name','actor_3_name','facenumber_in_poster',
                               'num_user_for_reviews','language','country','actor_2_facebook_likes',
                               'director_name', 'num_critic_for_reviews',
                               'duration','director_facebook_likes','actor_3_facebook_likes','actor_2_name',
                               'plot_keywords'],inplace=True)

# %%
movies.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.shape
# Out:
# (4737, 26)

# %%
movies.isnull().sum()
# Out:
# director_name                  0
# num_critic_for_reviews         0
# duration                       0
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                   0
# actor_1_facebook_likes         0
# gross                        644
# genres                         0
# actor_1_name                   0
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                   0
# facenumber_in_poster           0
# plot_keywords                  0
# num_user_for_reviews           0
# language                       0
# country                        0
# content_rating               169
# budget                       352
# title_year                     0
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                 209
# movie_facebook_likes           0
# dtype: int64

# %%
movies.dtypes
# Out:
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# num_user_for_reviews          object
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# ...

# %% [markdown]
# # fill null values

# %%
movies["content_rating"].value_counts()
# Out:
# R            2082
# PG-13        1436
# PG            681
# G             109
# Not Rated     100
# Unrated        58
# Approved       55
# X              13
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-G            3
# TV-14           3
# TV-PG           1
# Name: content_rating, dtype: int64

# %%
#fill the null values by mean
movies["gross"].fillna(movies["gross"].mean(),inplace=True)

# %%
# R most frequntly so i will fill the null values by R.
movies["content_rating"].fillna("R", inplace = True)

# %%
# in the budget column i fill the null values by MEAN.
movies["budget"].fillna(movies["budget"].mean(),inplace=True)

# %%
#in the aspect_ratio fill the null values by mean. 
movies["aspect_ratio"].fillna(movies["aspect_ratio"].mean(),inplace=True)

# %%
#now again check the null values 
movies.isnull().sum()
# Out:
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# # now drop the unwanted data(duplicates) or columns

# %%
movies.drop_duplicates(inplace=True)
movies.shape
# Out:
# (4695, 26)

# %%
#check the net profit made by the company (Gross-Budget) 

movies["Profit"]=round(movies['gross'].sub(movies['budget'], axis = 0),2)

# %%
movies.head()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 5     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
country_counts=movies["country"].value_counts()
country_counts
# Out:
# USA               3568
# UK                 420
# France             149
# Canada             107
# Germany             96
# Australia           53
# Spain               32
# India               27
# China               24
# Japan               21
# Italy               20
# Hong Kong           16
# New Zealand         14
# South Korea         12
# Russia              11
# Denmark             11
# Ireland             11
# Mexico              11
# Brazil               8
# South Africa         8
# Norway               7
# Netherlands          5
# Sweden               5
# Thailand             4
# Iran                 4
# Argentina            4
# Belgium              3
# Switzerland          3
# Israel               3
# West Germany         3
# Czech Republic       3
# Iceland              2
# Hungary              2
# Greece               2
# Taiwan               2
# Poland               2
# Romania              2
# Peru                 1
# Philippines          1
# Cambodia             1
# ...

# %%
vals = country_counts[:2].index
print (vals)
movies['country'] = movies.country.where(movies.country.isin(vals), 'other')
# Out:
# Index(['USA', 'UK'], dtype='object')

# %%
movies['country'].value_counts()
# Out:
# USA      3568
# other     707
# UK        420
# Name: country, dtype: int64

# %%
sns.countplot(movies["country"])
movies["country"].value_counts()
# Out:
# USA      3568
# other     707
# UK        420
# Name: country, dtype: int64

# %%
# Write your code for sorting the dataframe here
movies_by_profit = movies.sort_values("Profit",ascending = False)

# %%
top10 = movies_by_profit.head(10)
top10
# Out:
#           director_name  num_critic_for_reviews  duration  \
# 0         James Cameron                   723.0     178.0
# 29      Colin Trevorrow                   644.0     124.0
# 26        James Cameron                   315.0     194.0
# 3024       George Lucas                   282.0     125.0
# 3080   Steven Spielberg                   215.0     120.0
# 17          Joss Whedon                   703.0     173.0
# 509        Roger Allers                   186.0      73.0
# 240        George Lucas                   320.0     136.0
# 66    Christopher Nolan                   645.0     152.0
# 439           Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 29                      365.0                  1000.0         Judy Greer
# 26                        0.0                   794.0       Kate Winslet
# ...

# %%
#movies["Profit"].head(10)

# %%
movies = movies.drop(["director_facebook_likes","actor_1_facebook_likes","actor_2_facebook_likes",
                      "actor_3_facebook_likes","actor_2_name","cast_total_facebook_likes",
                      "actor_3_name","duration","facenumber_in_poster","content_rating","country",
                      "aspect_ratio","plot_keywords"],axis =1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                   movie_title  num_voted_users  \
# 0                                    AvatarÂ            886204
# 1  Pirates of the Caribbean: At World's EndÂ            471220
# 2                                   SpectreÂ            275868
# ...

# %%
movies.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'num_user_for_reviews', 'language', 'budget', 'title_year',
#        'imdb_score', 'movie_facebook_likes', 'Profit'],
#       dtype='object')

# %%
movies=movies.sort_values(by=['Profit'],ascending=False)
movies.head()
# Out:
#          director_name  num_critic_for_reviews        gross  \
# 0        James Cameron                   723.0  760505847.0
# 29     Colin Trevorrow                   644.0  652177271.0
# 26       James Cameron                   315.0  658672302.0
# 3024      George Lucas                   282.0  460935665.0
# 3080  Steven Spielberg                   215.0  434949459.0
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                       Drama|Romance    Leonardo DiCaprio
# 3024   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                     Family|Sci-Fi         Henry Thomas
#
#                                movie_title  num_voted_users  \
# 0                                 AvatarÂ            886204
# 29                        Jurassic WorldÂ            418214
# ...

# %%
plt.figure(num=None,figsize=(10,7), dpi=80) 
movies=movies[movies.Profit>100]
plt.scatter(movies['budget'], movies['Profit'])
plt.xlabel("Budget") #Labelling x
plt.ylabel("Profit") #Labelling y
plt.title("Budget-Profit Chart")
# Out:
# Text(0.5, 1.0, 'Budget-Profit Chart')

# %% [markdown]
# # top 10 movies

# %%
top10_movies=movies[["director_name",'movie_title']][0:10]  # CreatingNew Dataframe
top10_movies
# Out:
#           director_name                                  movie_title
# 0         James Cameron                                     AvatarÂ
# 29      Colin Trevorrow                             Jurassic WorldÂ
# 26        James Cameron                                    TitanicÂ
# 3024       George Lucas         Star Wars: Episode IV - A New HopeÂ
# 3080   Steven Spielberg                 E.T. the Extra-TerrestrialÂ
# 17          Joss Whedon                               The AvengersÂ
# 509        Roger Allers                              The Lion KingÂ
# 240        George Lucas  Star Wars: Episode I - The Phantom MenaceÂ
# 66    Christopher Nolan                            The Dark KnightÂ
# 439           Gary Ross                           The Hunger GamesÂ

# %% [markdown]
# # imdb 250

# %%
IMDb_Top_250=movies[['imdb_score','num_voted_users','movie_title','language']]

IMDb_sort= IMDb_Top_250.sort_values(by=['imdb_score'],ascending=False)

IMDb_Top_250=IMDb_sort[IMDb_Top_250.num_voted_users>25000]

IMDb_Top_250.head(250)
# Out:
#       imdb_score  num_voted_users  \
# 1937         9.3          1689764
# 3466         9.2          1155770
# 66           9.0          1676169
# 2837         9.0           790926
# 339          8.9          1215718
# ...          ...              ...
# 2611         7.8            60988
# 3985         7.8           160281
# 1638         7.8           192930
# 3101         7.8            43270
# 400          7.8           402645
#
#                                           movie_title language
# 1937                       The Shawshank RedemptionÂ   English
# 3466                                  The GodfatherÂ   English
# 66                                  The Dark KnightÂ   English
# 2837                         The Godfather: Part IIÂ   English
# 339   The Lord of the Rings: The Return of the KingÂ   English
# ...                                               ...      ...
# 2611                               The Color PurpleÂ   English
# ...

# %%
IMDb_Top_250["Rank"]=IMDb_Top_250['movie_title'].rank()
IMDb_Top_250['Rank']=IMDb_Top_250['Rank'].sort_values(ascending=True).values
IMDb_Top_250.head(15)
# Out:
#       imdb_score  num_voted_users  \
# 1937         9.3          1689764
# 3466         9.2          1155770
# 66           9.0          1676169
# 2837         9.0           790926
# 339          8.9          1215718
# 1874         8.9           865020
# 4822         8.9           447785
# 4498         8.9           503509
# 3355         8.9          1324680
# 97           8.8          1468200
# 2051         8.8           837759
# 836          8.8          1251222
# 270          8.8          1238746
# 3867         8.7           680041
# 4029         8.7           533200
#
#                                             movie_title    language  Rank
# 1937                         The Shawshank RedemptionÂ      English   1.0
# 3466                                    The GodfatherÂ      English   2.0
# 66                                    The Dark KnightÂ      English   3.0
# 2837                           The Godfather: Part IIÂ      English   4.0
# ...

# %% [markdown]
# # top 10 director

# %%
film=movies.groupby('director_name')

top10director=pd.DataFrame(film['imdb_score'].mean().sort_values(ascending=False))  #Convert to Dataframe
top10director=top10director.head(10)



top10director
# Out:
#                                   imdb_score
# director_name
# Sadyk Sher-Niyaz                       8.700
# Damien Chazelle                        8.500
# Sergio Leone                           8.500
# Florian Henckel von Donnersmarck       8.500
# Majid Majidi                           8.500
# Roger Allers                           8.500
# Raja Menon                             8.500
# Milos Forman                           8.500
# Christopher Nolan                      8.425
# Jay Oliva                              8.400

# %%
Meryl_Streep = movies[movies["actor_1_name"] == "Meryl Streep"]
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews         gross  \
# 1408   David Frankel                   208.0  1.247330e+08
# 1575  Sydney Pollack                    66.0  8.710000e+07
# 1204     Nora Ephron                   252.0  9.412543e+07
# 3641  Fred Zinnemann                    38.0  4.905322e+07
# 1618   David Frankel                   234.0  6.353601e+07
# 410     Nancy Meyers                   187.0  1.127035e+08
# 1752  Stephen Frears                    87.0  4.905322e+07
# 2781  Phyllida Lloyd                   331.0  2.995944e+07
# 1925  Stephen Daldry                   174.0  4.159783e+07
# 3135   Robert Altman                   211.0  2.033861e+07
# 1106   Curtis Hanson                    42.0  4.681575e+07
#
#                                     genres  actor_1_name  \
# 1408                  Comedy|Drama|Romance  Meryl Streep
# 1575               Biography|Drama|Romance  Meryl Streep
# 1204               Biography|Drama|Romance  Meryl Streep
# ...

# %%
Leo_Caprio = movies[movies["actor_1_name"] == "Leonardo DiCaprio"]
Leo_Caprio
# Out:
#                 director_name  num_critic_for_reviews        gross  \
# 26              James Cameron                   315.0  658672302.0
# 97          Christopher Nolan                   642.0  292568851.0
# 911          Steven Spielberg                   194.0  164435221.0
# 296         Quentin Tarantino                   765.0  162804648.0
# 179   Alejandro G. IÃ±Ã¡rritu                   556.0  183635922.0
# 452           Martin Scorsese                   490.0  127968405.0
# 361           Martin Scorsese                   352.0  132373442.0
# 3476             Baz Luhrmann                   490.0  144812796.0
# 50               Baz Luhrmann                   490.0  144812796.0
# 2757             Baz Luhrmann                   106.0   46338728.0
# 1422          Randall Wallace                    83.0   56876365.0
# 308           Martin Scorsese                   606.0  116866727.0
# 1453           Clint Eastwood                   392.0   37304950.0
#
# ...

# %%
Brad_Pitt = movies[movies["actor_1_name"] == "Brad Pitt"]
Brad_Pitt.head()
# Out:
#           director_name  num_critic_for_reviews         gross  \
# 400   Steven Soderbergh                   186.0  1.834058e+08
# 255          Doug Liman                   233.0  1.863361e+08
# 4749        Tom DiCillo                    10.0  4.905322e+07
# 940         Neil Jordan                   120.0  1.052646e+08
# 470          David Ayer                   406.0  8.570712e+07
#
#                                     genres actor_1_name  \
# 400                         Crime|Thriller    Brad Pitt
# 255   Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 4749                  Comedy|Music|Romance    Brad Pitt
# 940                   Drama|Fantasy|Horror    Brad Pitt
# 470                       Action|Drama|War    Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 400                                    Ocean's ElevenÂ            402645
# 255                                  Mr. & Mrs. SmithÂ            348861
# ...

# %%
Combined=Meryl_Streep.append(Leo_Caprio).append(Brad_Pitt)

Combined
# Out:
#                 director_name  num_critic_for_reviews         gross  \
# 1408            David Frankel                   208.0  1.247330e+08
# 1575           Sydney Pollack                    66.0  8.710000e+07
# 1204              Nora Ephron                   252.0  9.412543e+07
# 3641           Fred Zinnemann                    38.0  4.905322e+07
# 1618            David Frankel                   234.0  6.353601e+07
# 410              Nancy Meyers                   187.0  1.127035e+08
# 1752           Stephen Frears                    87.0  4.905322e+07
# 2781           Phyllida Lloyd                   331.0  2.995944e+07
# 1925           Stephen Daldry                   174.0  4.159783e+07
# 3135            Robert Altman                   211.0  2.033861e+07
# 1106            Curtis Hanson                    42.0  4.681575e+07
# 26              James Cameron                   315.0  6.586723e+08
# 97          Christopher Nolan                   642.0  2.925689e+08
# ...

# %%
Actor_name=Combined.groupby('actor_1_name')
Actor_name

# %%
Critic_reviews=Actor_name['num_critic_for_reviews'].mean().sort_values(ascending=False)
Critic_reviews
# Out:
# actor_1_name
# Leonardo DiCaprio    421.615385
# Brad Pitt            205.428571
# Meryl Streep         166.363636
# Name: num_critic_for_reviews, dtype: float64

# %%
by_decade=movies.groupby('title_year')
by_decade['num_voted_users'].sum()

by_decade=pd.DataFrame(by_decade['num_voted_users'].sum())
by_decade
# Out:
#             num_voted_users
# title_year
# 1929.0                 4546
# 1930.0                 3753
# 1932.0                 3519
# 1933.0                12073
# 1934.0                64888
# ...                     ...
# 2012.0             15605762
# 2013.0             16985371
# 2014.0             14957050
# 2015.0              9284617
# 2016.0              2246689
#
# [87 rows x 1 columns]
